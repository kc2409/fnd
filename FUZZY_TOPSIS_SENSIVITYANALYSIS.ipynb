# %% [markdown]
# <a href="https://colab.research.google.com/github/kc2409/fnd/blob/main/FUZZY_TOPSIS_SENSIVITYANALYSIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install numpy pandas scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd

# Load the fuzzy evaluation matrix
data = pd.read_excel('date.xlsx')  # Replace 'data.csv' with the path to your data file

# %%
import skfuzzy as fuzz

# Define the fuzzy weights
weights = list([
    [(0.04, 0.062, 0.095), (0.069, 0.103, 0.15), (0.403, 0.552, 0.75), (0.165, 0.238, 0.342), (0.032, 0.046, 0.074)]
])

# %%
fuzzy_matrix = data * weights
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-fc69e0e7cb7a> in <cell line: 1>()
# ----> 1 fuzzy_matrix = data * weights
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __mul__(self, other)
#     116     @unpack_zerodim_and_defer("__mul__")
#     117     def __mul__(self, other):
# --> 118         return self._arith_method(other, operator.mul)
#     119
#     120     @unpack_zerodim_and_defer("__rmul__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _arith_method(self, other, op)
#    7590         other = ops.maybe_prepare_scalar_for_op(other, (self.shape[axis],))
# ...

# %%
import pandas as pd
import skfuzzy as fuzz

# Step 1: Load the fuzzy evaluation matrix
data = pd.read_excel('date.xlsx')  # Replace 'data.csv' with the path to your data file

# Step 2: Define the fuzzy weights
weights = list([
    [(0.04, 0.062, 0.095), (0.069, 0.103, 0.15), (0.403, 0.552, 0.75), (0.165, 0.238, 0.342), (0.032, 0.046, 0.074)]
])

# Step 3: Calculate the Fuzzy Decision Matrix
fuzzy_matrix = data * weights[0]

# Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
ideal_solution = fuzzy_matrix.max()
negative_ideal_solution = fuzzy_matrix.min()

# Step 5: Calculate the Fuzzy Separation Measures
def calculate_closeness(row, ideal, negative_ideal):
    distance_to_ideal = fuzz.interp_membership(data.columns, ideal, row)
    distance_to_negative_ideal = fuzz.interp_membership(data.columns, negative_ideal, row)
    return distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal)

closeness_scores = fuzzy_matrix.apply(lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution), axis=1)

# Step 6: Perform Sensitivity Analysis
sensitivity_weights = [
    [(0.04, 0.062, 0.095), (0.069, 0.103, 0.15), (0.403, 0.552, 0.75), (0.165, 0.238, 0.342), (0.032, 0.046, 0.074)],  # Initial fuzzy weights
    # Add additional adjusted fuzzy weights as needed
]

for weights in sensitivity_weights:
    fuzzy_matrix = data * weights
    ideal_solution = fuzzy_matrix.max()
    negative_ideal_solution = fuzzy_matrix.min()
    closeness_scores = fuzzy_matrix.apply(lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution), axis=1)
    ranked_alternatives = closeness_scores.rank(ascending=False)
    print(ranked_alternatives)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-e23330813083> in <cell line: 25>()
#      23     return distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal)
#      24
# ---> 25 closeness_scores = fuzzy_matrix.apply(lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution), axis=1)
#      26
#      27 # Step 6: Perform Sensitivity Analysis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9566             kwargs=kwargs,
#    9567         )
# -> 9568         return op.apply().__finalize__(self, method="apply")
#    9569
#    9570     def applymap(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#     762             return self.apply_raw()
#     763
# --> 764         return self.apply_standard()
#     765
# ...

# %%
import pandas as pd
import skfuzzy as fuzz
import numpy as np

# Step 1: Load the fuzzy evaluation matrix
data = pd.read_excel('date.xlsx')  # Replace 'data.csv' with the path to your data file

# Step 2: Define the fuzzy weights
weights = list([
    [(0.04, 0.062, 0.095), (0.069, 0.103, 0.15), (0.403, 0.552, 0.75), (0.165, 0.238, 0.342), (0.032, 0.046, 0.074)]
])

# Step 3: Calculate the Fuzzy Decision Matrix
fuzzy_matrix = data * np.array(weights[0], dtype=float)

# Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
ideal_solution = fuzzy_matrix.max()
negative_ideal_solution = fuzzy_matrix.min()

# Step 5: Calculate the Fuzzy Separation Measures
def calculate_closeness(row, ideal, negative_ideal):
    distance_to_ideal = fuzz.interp_membership(data.columns, ideal, row)
    distance_to_negative_ideal = fuzz.interp_membership(data.columns, negative_ideal, row)
    return distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal)

closeness_scores = fuzzy_matrix.apply(lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution), axis=1)

# Step 6: Perform Sensitivity Analysis
sensitivity_weights = [
    [(0.04, 0.062, 0.095), (0.069, 0.103, 0.15), (0.403, 0.552, 0.75), (0.165, 0.238, 0.342), (0.032, 0.046, 0.074)],  # Initial fuzzy weights
    # Add additional adjusted fuzzy weights as needed
]

for weights in sensitivity_weights:
    fuzzy_matrix = data * np.array(weights, dtype=float)
    ideal_solution = fuzzy_matrix.max()
    negative_ideal_solution = fuzzy_matrix.min()
    closeness_scores = fuzzy_matrix.apply(lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution), axis=1)
    ranked_alternatives = closeness_scores.rank(ascending=False)
    print(ranked_alternatives)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-c93182ae1249> in <cell line: 14>()
#      12
#      13 # Step 3: Calculate the Fuzzy Decision Matrix
# ---> 14 fuzzy_matrix = data * np.array(weights[0], dtype=float)
#      15
#      16 # Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __mul__(self, other)
#     116     @unpack_zerodim_and_defer("__mul__")
#     117     def __mul__(self, other):
# --> 118         return self._arith_method(other, operator.mul)
#     119
#     120     @unpack_zerodim_and_defer("__rmul__")
#
# ...

# %%
import pandas as pd
import skfuzzy as fuzz
import numpy as np

# Step 1: Load the fuzzy evaluation matrix
data = pd.read_excel('date.xlsx')  # Replace 'data.csv' with the path to your data file

# Step 2: Define the fuzzy weights
weights = [
    [(0.04, 0.062, 0.095), (0.069, 0.103, 0.15), (0.403, 0.552, 0.75), (0.165, 0.238, 0.342), (0.032, 0.046, 0.074)] for _ in range(len(data))
]

# Step 3: Calculate the Fuzzy Decision Matrix
fuzzy_matrix = data * weights

# Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
ideal_solution = fuzzy_matrix.max()
negative_ideal_solution = fuzzy_matrix.min()

# Step 5: Calculate the Fuzzy Separation Measures
def calculate_closeness(row, ideal, negative_ideal):
    distance_to_ideal = fuzz.interp_membership(data.columns, ideal, row)
    distance_to_negative_ideal = fuzz.interp_membership(data.columns, negative_ideal, row)
    return distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal)

closeness_scores = fuzzy_matrix.apply(lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution), axis=1)

# Step 6: Perform Sensitivity Analysis
sensitivity_weights = [
    [
        (0.04, 0.062, 0.095),
        (0.069, 0.103, 0.15),
        (0.403, 0.552, 0.75),
        (0.165, 0.238, 0.342),
        (0.032, 0.046, 0.074)
    ],  # Initial fuzzy weights
    # Add additional adjusted fuzzy weights as needed
    [
        (0.05, 0.071, 0.105),
        (0.08, 0.11, 0.16),
        (0.413, 0.562, 0.77),
        (0.16, 0.233, 0.335),
        (0.03, 0.045, 0.073)
    ],  # Additional fuzzy weights
    # Add more sets of fuzzy weights as needed
]

for weights in sensitivity_weights:
    fuzzy_matrix = data * np.array([weights] * len(data), dtype=float)
    ideal_solution = fuzzy_matrix.max()
    negative_ideal_solution = fuzzy_matrix.min()
    closeness_scores = fuzzy_matrix.apply(lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution), axis=1)
    ranked_alternatives = closeness_scores.rank(ascending=False)
    print(ranked_alternatives)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-c18979828da0> in <cell line: 14>()
#      12
#      13 # Step 3: Calculate the Fuzzy Decision Matrix
# ---> 14 fuzzy_matrix = data * weights
#      15
#      16 # Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __mul__(self, other)
#     116     @unpack_zerodim_and_defer("__mul__")
#     117     def __mul__(self, other):
# --> 118         return self._arith_method(other, operator.mul)
#     119
#     120     @unpack_zerodim_and_defer("__rmul__")
#
# ...

# %%
import pandas as pd
import skfuzzy as fuzz
import numpy as np

# Step 1: Load the fuzzy evaluation matrix
data = pd.read_excel('date.xlsx')  # Replace 'data.csv' with the path to your data file

# Step 2: Define the fuzzy weights
weights = np.array([
    [[0.04, 0.062, 0.095], [0.069, 0.103, 0.15], [0.403, 0.552, 0.75], [0.165, 0.238, 0.342], [0.032, 0.046, 0.074]]
] * len(data), dtype=float)

# Step 3: Calculate the Fuzzy Decision Matrix
fuzzy_matrix = data * weights

# Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
ideal_solution = fuzzy_matrix.max()
negative_ideal_solution = fuzzy_matrix.min()

# Step 5: Calculate the Fuzzy Separation Measures
def calculate_closeness(row, ideal, negative_ideal):
    distance_to_ideal = fuzz.interp_membership(data.columns, ideal, row)
    distance_to_negative_ideal = fuzz.interp_membership(data.columns, negative_ideal, row)
    return distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal)

closeness_scores = fuzzy_matrix.apply(lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution), axis=1)

# Step 6: Perform Sensitivity Analysis
sensitivity_weights = np.array([
    [
        [0.04, 0.062, 0.095],
        [0.069, 0.103, 0.15],
        [0.403, 0.552, 0.75],
        [0.165, 0.238, 0.342],
        [0.032, 0.046, 0.074]
    ],  # Initial fuzzy weights
    # Add additional adjusted fuzzy weights as needed
    [
        [0.05, 0.071, 0.105],
        [0.08, 0.11, 0.16],
        [0.413, 0.562, 0.77],
        [0.16, 0.233, 0.335],
        [0.03, 0.045, 0.073]
    ],  # Additional fuzzy weights
    # Add more sets of fuzzy weights as needed
])

for weights in sensitivity_weights:
    fuzzy_matrix = data * np.array([weights] * len(data), dtype=float)
    ideal_solution = fuzzy_matrix.max()
    negative_ideal_solution = fuzzy_matrix.min()
    closeness_scores = fuzzy_matrix.apply(lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution), axis=1)
    ranked_alternatives = closeness_scores.rank(ascending=False)
    print(ranked_alternatives)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-eb14e671aad3> in <cell line: 14>()
#      12
#      13 # Step 3: Calculate the Fuzzy Decision Matrix
# ---> 14 fuzzy_matrix = data * weights
#      15
#      16 # Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __mul__(self, other)
#     116     @unpack_zerodim_and_defer("__mul__")
#     117     def __mul__(self, other):
# --> 118         return self._arith_method(other, operator.mul)
#     119
#     120     @unpack_zerodim_and_defer("__rmul__")
#
# ...

# %%
import pandas as pd
import skfuzzy as fuzz
import numpy as np

# Step 1: Load the fuzzy evaluation matrix
data = pd.read_excel('date.xlsx')  # Replace 'data.csv' with the path to your data file

# Step 2: Define the fuzzy weights
weights = np.array([
    [[0.04, 0.062, 0.095], [0.069, 0.103, 0.15], [0.403, 0.552, 0.75], [0.165, 0.238, 0.342], [0.032, 0.046, 0.074]]
] * len(data), dtype=float)

# Step 3: Calculate the Fuzzy Decision Matrix
fuzzy_matrix = np.multiply(data.values[:, :, np.newaxis], weights)

# Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
ideal_solution = fuzzy_matrix.max(axis=0)
negative_ideal_solution = fuzzy_matrix.min(axis=0)

# Step 5: Calculate the Fuzzy Separation Measures
def calculate_closeness(row, ideal, negative_ideal):
    distance_to_ideal = fuzz.interp_membership(data.columns, ideal, row)
    distance_to_negative_ideal = fuzz.interp_membership(data.columns, negative_ideal, row)
    return distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal)

closeness_scores = np.apply_along_axis(lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution), axis=1, arr=fuzzy_matrix)

# Step 6: Perform Sensitivity Analysis
sensitivity_weights = np.array([
    [
        [0.04, 0.062, 0.095],
        [0.069, 0.103, 0.15],
        [0.403, 0.552, 0.75],
        [0.165, 0.238, 0.342],
        [0.032, 0.046, 0.074]
    ],  # Initial fuzzy weights
    # Add additional adjusted fuzzy weights as needed
    [
        [0.05, 0.071, 0.105],
        [0.08, 0.11, 0.16],
        [0.413, 0.562, 0.77],
        [0.16, 0.233, 0.335],
        [0.03, 0.045, 0.073]
    ],  # Additional fuzzy weights
    # Add more sets of fuzzy weights as needed
])

for weights in sensitivity_weights:
    fuzzy_matrix = np.multiply(data.values[:, :, np.newaxis], weights)
    ideal_solution = fuzzy_matrix.max(axis=0)
    negative_ideal_solution = fuzzy_matrix.min(axis=0)
    closeness_scores = np.apply_along_axis(lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution), axis=1, arr=fuzzy_matrix)
    ranked_alternatives = pd.Series(closeness_scores).rank(ascending=False)
    print(ranked_alternatives)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-b9677ead8d49> in <cell line: 26>()
#      24     return distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal)
#      25
# ---> 26 closeness_scores = np.apply_along_axis(lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution), axis=1, arr=fuzzy_matrix)
#      27
#      28 # Step 6: Perform Sensitivity Analysis
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in apply_along_axis(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/shape_base.py in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     377             'Cannot apply_along_axis when any iteration dimensions are 0'
#     378         ) from None
# --> 379     res = asanyarray(func1d(inarr_view[ind0], *args, **kwargs))
#     380
# ...

# %%
import pandas as pd
import skfuzzy as fuzz
import numpy as np

# Step 1: Load the fuzzy evaluation matrix
data = pd.read_excel('date.xlsx')  # Replace 'data.csv' with the path to your data file

# Step 2: Define the fuzzy weights
weights = np.array([
    [[0.04, 0.062, 0.095], [0.069, 0.103, 0.15], [0.403, 0.552, 0.75], [0.165, 0.238, 0.342], [0.032, 0.046, 0.074]]
] * len(data), dtype=float)

# Step 3: Calculate the Fuzzy Decision Matrix
fuzzy_matrix = np.multiply(data.values[:, :, np.newaxis], weights)

# Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
ideal_solution = fuzzy_matrix.max(axis=0)
negative_ideal_solution = fuzzy_matrix.min(axis=0)

# Step 5: Calculate the Fuzzy Separation Measures
def calculate_closeness(row, ideal, negative_ideal):
    closeness_scores = []
    for i in range(len(row)):
        distance_to_ideal = fuzz.interp_membership(data.columns, ideal[:, i], row[i])
        distance_to_negative_ideal = fuzz.interp_membership(data.columns, negative_ideal[:, i], row[i])
        closeness_scores.append(distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal))
    return closeness_scores

closeness_scores = []
for row in fuzzy_matrix:
    closeness_scores.append(calculate_closeness(row, ideal_solution, negative_ideal_solution))

# Step 6: Perform Sensitivity Analysis
sensitivity_weights = np.array([
    [
        [0.04, 0.062, 0.095],
        [0.069, 0.103, 0.15],
        [0.403, 0.552, 0.75],
        [0.165, 0.238, 0.342],
        [0.032, 0.046, 0.074]
    ],  # Initial fuzzy weights
    # Add additional adjusted fuzzy weights as needed
    [
        [0.05, 0.071, 0.105],
        [0.08, 0.11, 0.16],
        [0.413, 0.562, 0.77],
        [0.16, 0.233, 0.335],
        [0.03, 0.045, 0.073]
    ],  # Additional fuzzy weights
    # Add more sets of fuzzy weights as needed
])

for weights in sensitivity_weights:
    fuzzy_matrix = np.multiply(data.values[:, :, np.newaxis], weights)
    ideal_solution = fuzzy_matrix.max(axis=0)
    negative_ideal_solution = fuzzy_matrix.min(axis=0)
    closeness_scores = []
    for row in fuzzy_matrix:
        closeness_scores.append(calculate_closeness(row, ideal_solution, negative_ideal_solution))
    ranked_alternatives = pd.Series(np.mean(closeness_scores, axis=1)).rank(ascending=False)
    print(ranked_alternatives)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-16850e02c4f5> in <cell line: 30>()
#      29 closeness_scores = []
#      30 for row in fuzzy_matrix:
# ---> 31     closeness_scores.append(calculate_closeness(row, ideal_solution, negative_ideal_solution))
#      32
#      33 # Step 6: Perform Sensitivity Analysis
#
# <ipython-input-18-16850e02c4f5> in calculate_closeness(row, ideal, negative_ideal)
#      22     closeness_scores = []
#      23     for i in range(len(row)):
# ---> 24         distance_to_ideal = fuzz.interp_membership(data.columns, ideal[:, i], row[i])
#      25         distance_to_negative_ideal = fuzz.interp_membership(data.columns, negative_ideal[:, i], row[i])
#      26         closeness_scores.append(distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal))
#
# ...

# %%
import pandas as pd
import skfuzzy as fuzz
import numpy as np

# Step 1: Load the fuzzy evaluation matrix
data = pd.read_excel('date.xlsx')  # Replace 'data.csv' with the path to your data file

# Step 2: Define the fuzzy weights
weights = np.array([
    [[0.04, 0.062, 0.095], [0.069, 0.103, 0.15], [0.403, 0.552, 0.75], [0.165, 0.238, 0.342], [0.032, 0.046, 0.074]]
] * len(data), dtype=float)

# Step 3: Calculate the Fuzzy Decision Matrix
fuzzy_matrix = np.multiply(data.values[:, 1:, np.newaxis], weights)

# Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
ideal_solution = fuzzy_matrix.max(axis=0)
negative_ideal_solution = fuzzy_matrix.min(axis=0)

# Step 5: Calculate the Fuzzy Separation Measures
def calculate_closeness(row, ideal, negative_ideal):
    closeness_scores = []
    for i in range(len(row)):
        distance_to_ideal = fuzz.interp_membership(data.columns[1:], ideal[:, i], row[i])
        distance_to_negative_ideal = fuzz.interp_membership(data.columns[1:], negative_ideal[:, i], row[i])
        closeness_scores.append(distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal))
    return closeness_scores

closeness_scores = []
for row in fuzzy_matrix:
    closeness_scores.append(calculate_closeness(row, ideal_solution, negative_ideal_solution))

# Step 6: Perform Sensitivity Analysis
sensitivity_weights = np.array([
    [
        [0.04, 0.062, 0.095],
        [0.069, 0.103, 0.15],
        [0.403, 0.552, 0.75],
        [0.165, 0.238, 0.342],
        [0.032, 0.046, 0.074]
    ],  # Initial fuzzy weights
    # Add additional adjusted fuzzy weights as needed
    [
        [0.05, 0.071, 0.105],
        [0.08, 0.11, 0.16],
        [0.413, 0.562, 0.77],
        [0.16, 0.233, 0.335],
        [0.03, 0.045, 0.073]
    ],  # Additional fuzzy weights
    # Add more sets of fuzzy weights as needed
])

for weights in sensitivity_weights:
    fuzzy_matrix = np.multiply(data.values[:, 1:, np.newaxis], weights)
    ideal_solution = fuzzy_matrix.max(axis=0)
    negative_ideal_solution = fuzzy_matrix.min(axis=0)
    closeness_scores = []
    for row in fuzzy_matrix:
        closeness_scores.append(calculate_closeness(row, ideal_solution, negative_ideal_solution))
    ranked_alternatives = np.mean(closeness_scores, axis=1)
    print(ranked_alternatives)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-184d5a3c4bd2> in <cell line: 14>()
#      12
#      13 # Step 3: Calculate the Fuzzy Decision Matrix
# ---> 14 fuzzy_matrix = np.multiply(data.values[:, 1:, np.newaxis], weights)
#      15
#      16 # Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
#
# ValueError: operands could not be broadcast together with shapes (18,4,1) (18,5,3)

# %%
import numpy as np
import skfuzzy as fuzz

# Step 1: Load the fuzzy evaluation matrix
data = np.array([
    [84, 75, 40, 187, 3],
    [76, 77, 30, 195, 2],
    [27, 85, 25, 272, 4],
    [110, 86, 22, 236, 5],
    [94, 74, 38, 287, 3],
    [102, 62, 10, 242, 6],
    [82, 73, 24, 168, 3],
    [63, 92, 38, 396, 5],
    [55, 77, 26, 144, 2],
    [61, 69, 18, 137, 3],
    [122, 54, 24, 142, 6],
    [75, 57, 30, 196, 5],
    [80, 77, 55, 247, 1],
    [121, 61, 39, 148, 3],
    [125, 69, 8, 294, 4],
    [76, 94, 6, 249, 6],
    [114, 88, 55, 121, 2],
    [65, 78, 48, 269, 1]
])

# Step 2: Define the initial fuzzy weights
initial_weights = np.array([
    [0.04, 0.062, 0.095],
    [0.069, 0.103, 0.15],
    [0.403, 0.552, 0.75],
    [0.165, 0.238, 0.342],
    [0.032, 0.046, 0.074]
])

# Step 3: Define the sensitivity weights
sensitivity_weights = [
    np.array([
        [0.05, 0.071, 0.105],
        [0.07, 0.104, 0.151],
        [0.4, 0.55, 0.74],
        [0.16, 0.24, 0.34],
        [0.03, 0.045, 0.073]
    ]),
    np.array([
        [0.03, 0.045, 0.073],
        [0.05, 0.07, 0.1],
        [0.41, 0.56, 0.76],
        [0.17, 0.25, 0.35],
        [0.04, 0.06, 0.09]
    ])
]

# Step 4: Define the fuzzy TOPSIS function
def fuzzy_topsis(data, weights):
    fuzzy_matrix = np.multiply(data, weights)
    ideal_solution = fuzzy_matrix.max(axis=0)
    negative_ideal_solution = fuzzy_matrix.min(axis=0)

    def calculate_closeness(row, ideal, negative_ideal):
        distance_to_ideal = fuzz.interp_membership(range(len(row)), ideal, row)
        distance_to_negative_ideal = fuzz.interp_membership(range(len(row)), negative_ideal, row)
        return distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal)

    closeness_scores = np.apply_along_axis(
        lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution),
        axis=1,
        arr=fuzzy_matrix
    )

    return np.mean(closeness_scores, axis=1)

# Step 5: Perform sensitivity analysis
results = []
results.append(fuzzy_topsis(data, initial_weights))
for weights in sensitivity_weights:
    results.append(fuzzy_topsis(data, weights))

# Step 6: Print the results
for i, result in enumerate(results):
    print(f"Sensitivity Weight {i+1}: {result}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-26acfd41831b> in <cell line: 74>()
#      72 # Step 5: Perform sensitivity analysis
#      73 results = []
# ---> 74 results.append(fuzzy_topsis(data, initial_weights))
#      75 for weights in sensitivity_weights:
#      76     results.append(fuzzy_topsis(data, weights))
#
# <ipython-input-20-26acfd41831b> in fuzzy_topsis(data, weights)
#      53 # Step 4: Define the fuzzy TOPSIS function
#      54 def fuzzy_topsis(data, weights):
# ---> 55     fuzzy_matrix = np.multiply(data, weights)
#      56     ideal_solution = fuzzy_matrix.max(axis=0)
#      57     negative_ideal_solution = fuzzy_matrix.min(axis=0)
#
# ValueError: operands could not be broadcast together with shapes (18,5) (5,3)

# %%
import numpy as np
import skfuzzy as fuzz

# Step 1: Load the fuzzy evaluation matrix
data = np.array([
    [84, 75, 40, 187, 3],
    [76, 77, 30, 195, 2],
    [27, 85, 25, 272, 4],
    [110, 86, 22, 236, 5],
    [94, 74, 38, 287, 3],
    [102, 62, 10, 242, 6],
    [82, 73, 24, 168, 3],
    [63, 92, 38, 396, 5],
    [55, 77, 26, 144, 2],
    [61, 69, 18, 137, 3],
    [122, 54, 24, 142, 6],
    [75, 57, 30, 196, 5],
    [80, 77, 55, 247, 1],
    [121, 61, 39, 148, 3],
    [125, 69, 8, 294, 4],
    [76, 94, 6, 249, 6],
    [114, 88, 55, 121, 2],
    [65, 78, 48, 269, 1]
])

# Step 2: Define the initial fuzzy weights
initial_weights = np.array([
    [0.04, 0.062, 0.095, 0.04, 0.062],
    [0.069, 0.103, 0.15, 0.069, 0.103],
    [0.403, 0.552, 0.75, 0.403, 0.552],
    [0.165, 0.238, 0.342, 0.165, 0.238],
    [0.032, 0.046, 0.074, 0.032, 0.046]
])

# Step 3: Define the sensitivity weights
sensitivity_weights = [
    np.array([
        [0.05, 0.071, 0.105, 0.05, 0.071],
        [0.07, 0.104, 0.151, 0.07, 0.104],
        [0.4, 0.55, 0.74, 0.4, 0.55],
        [0.16, 0.24, 0.34, 0.16, 0.24],
        [0.03, 0.045, 0.073, 0.03, 0.045]
    ]),
    np.array([
        [0.03, 0.045, 0.073, 0.03, 0.045],
        [0.05, 0.071, 0.105, 0.05, 0.071],
        [0.4, 0.55, 0.74, 0.4, 0.55],
        [0.16, 0.24, 0.34, 0.16, 0.24],
        [0.07, 0.104, 0.151, 0.07, 0.104]
    ]),
    np.array([
        [0.06, 0.083, 0.123, 0.06, 0.083],
        [0.07, 0.104, 0.151, 0.07, 0.104],
        [0.4, 0.55, 0.74, 0.4, 0.55],
        [0.16, 0.24, 0.34, 0.16, 0.24],
        [0.04, 0.059, 0.092, 0.04, 0.059]
    ])
]

# Step 4: Define the fuzzy TOPSIS function
def fuzzy_topsis(data, weights):
    fuzzy_matrix = np.multiply(data, weights)
    ideal_solution = fuzzy_matrix.max(axis=0)
    negative_ideal_solution = fuzzy_matrix.min(axis=0)

    def calculate_closeness(row, ideal, negative_ideal):
        distance_to_ideal = fuzz.euclidean(row, ideal)
        distance_to_negative_ideal = fuzz.euclidean(row, negative_ideal)
        return distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal)

    closeness_scores = np.apply_along_axis(
        lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution),
        axis=1,
        arr=fuzzy_matrix
    )

    return np.mean(closeness_scores)

# Step 5: Perform sensitivity analysis
results = []
results.append(fuzzy_topsis(data, initial_weights))
for weights in sensitivity_weights:
    results.append(fuzzy_topsis(data, weights))

# Step 6: Print the results
for i, result in enumerate(results):
    print(f"Sensitivity Weight {i+1}: {result}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-410c1d1dcdcb> in <cell line: 81>()
#      79 # Step 5: Perform sensitivity analysis
#      80 results = []
# ---> 81 results.append(fuzzy_topsis(data, initial_weights))
#      82 for weights in sensitivity_weights:
#      83     results.append(fuzzy_topsis(data, weights))
#
# <ipython-input-21-410c1d1dcdcb> in fuzzy_topsis(data, weights)
#      60 # Step 4: Define the fuzzy TOPSIS function
#      61 def fuzzy_topsis(data, weights):
# ---> 62     fuzzy_matrix = np.multiply(data, weights)
#      63     ideal_solution = fuzzy_matrix.max(axis=0)
#      64     negative_ideal_solution = fuzzy_matrix.min(axis=0)
#
# ValueError: operands could not be broadcast together with shapes (18,5) (5,5)

# %%
import numpy as np
from scipy.spatial import distance
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import rankdata
import pandas as pd
import skfuzzy as fuzz

# Step 1: Define the dataset
data = np.array([
    [84, 75, 40, 187, 3],
    [76, 77, 30, 195, 2],
    [27, 85, 25, 272, 4],
    [110, 86, 22, 236, 5],
    [94, 74, 38, 287, 3],
    [102, 62, 10, 242, 6],
    [82, 73, 24, 168, 3],
    [63, 92, 38, 396, 5],
    [55, 77, 26, 144, 2],
    [61, 69, 18, 137, 3],
    [122, 54, 24, 142, 6],
    [75, 57, 30, 196, 5],
    [80, 77, 55, 247, 1],
    [121, 61, 39, 148, 3],
    [125, 69, 8, 294, 4],
    [76, 94, 6, 249, 6],
    [114, 88, 55, 121, 2],
    [65, 78, 48, 269, 1]
])

# Step 2: Define the initial weights
initial_weights = np.array([
    [0.04, 0.062, 0.095],
    [0.069, 0.103, 0.15],
    [0.403, 0.552, 0.75],
    [0.165, 0.238, 0.342],
    [0.032, 0.046, 0.074]
])

# Step 3: Calculate the Fuzzy Decision Matrix
fuzzy_matrix = data * initial_weights

# Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
ideal_solution = fuzzy_matrix.max(axis=0)
negative_ideal_solution = fuzzy_matrix.min(axis=0)

# Step 5: Define the fuzzy TOPSIS function
def fuzzy_topsis(data, weights):
    fuzzy_matrix = data * weights
    ideal_solution = fuzzy_matrix.max(axis=0)
    negative_ideal_solution = fuzzy_matrix.min(axis=0)

    def calculate_closeness(row, ideal, negative_ideal):
        distance_to_ideal = fuzz.euclidean(row, ideal)
        distance_to_negative_ideal = fuzz.euclidean(row, negative_ideal)
        return distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal)

    closeness_scores = np.apply_along_axis(
        lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution),
        axis=1,
        arr=fuzzy_matrix
    )

    return np.mean(closeness_scores)

# Step 6: Perform sensitivity analysis
sensitivity_weights = [
    np.array([
        [0.04, 0.062, 0.095],
        [0.069, 0.103, 0.15],
        [0.403, 0.552, 0.75],
        [0.165, 0.238, 0.342],
        [0.032, 0.046, 0.074]
    ]),
    np.array([
        [0.041, 0.063, 0.096],
        [0.07, 0.104, 0.151],
        [0.404, 0.553, 0.751],
        [0.166, 0.239, 0.343],
        [0.033, 0.047, 0.075]
    ]),
    np.array([
        [0.042, 0.064, 0.097],
        [0.071, 0.105, 0.152],
        [0.405, 0.554, 0.752],
        [0.167, 0.24, 0.344],
        [0.034, 0.048, 0.076]
    ])
]

results = []
results.append(fuzzy_topsis(data, initial_weights))
for weights in sensitivity_weights:
    results.append(fuzzy_topsis(data, weights))

# Step 7: Print the results
for i, result in enumerate(results):
    print(f"Sensitivity Weight {i+1}: {result}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-f5f71bc45030> in <cell line: 40>()
#      38
#      39 # Step 3: Calculate the Fuzzy Decision Matrix
# ---> 40 fuzzy_matrix = data * initial_weights
#      41
#      42 # Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
#
# ValueError: operands could not be broadcast together with shapes (18,5) (5,3)

# %%
import numpy as np
from scipy.spatial import distance
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import rankdata
import pandas as pd
import skfuzzy as fuzz

# Step 1: Define the dataset
data = np.array([
    [84, 75, 40, 187, 3],
    [76, 77, 30, 195, 2],
    [27, 85, 25, 272, 4],
    [110, 86, 22, 236, 5],
    [94, 74, 38, 287, 3],
    [102, 62, 10, 242, 6],
    [82, 73, 24, 168, 3],
    [63, 92, 38, 396, 5],
    [55, 77, 26, 144, 2],
    [61, 69, 18, 137, 3],
    [122, 54, 24, 142, 6],
    [75, 57, 30, 196, 5],
    [80, 77, 55, 247, 1],
    [121, 61, 39, 148, 3],
    [125, 69, 8, 294, 4],
    [76, 94, 6, 249, 6],
    [114, 88, 55, 121, 2],
    [65, 78, 48, 269, 1]
])

# Step 2: Define the initial weights
initial_weights = np.array([
    [0.04, 0.062, 0.095],
    [0.069, 0.103, 0.15],
    [0.403, 0.552, 0.75],
    [0.165, 0.238, 0.342],
    [0.032, 0.046, 0.074]
])

# Step 3: Calculate the Fuzzy Decision Matrix
fuzzy_matrix = data * initial_weights.T

# Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
ideal_solution = fuzzy_matrix.max(axis=0)
negative_ideal_solution = fuzzy_matrix.min(axis=0)

# Step 5: Define the fuzzy TOPSIS function
def fuzzy_topsis(data, weights):
    fuzzy_matrix = data * weights.T
    ideal_solution = fuzzy_matrix.max(axis=0)
    negative_ideal_solution = fuzzy_matrix.min(axis=0)

    def calculate_closeness(row, ideal, negative_ideal):
        distance_to_ideal = fuzz.euclidean(row, ideal)
        distance_to_negative_ideal = fuzz.euclidean(row, negative_ideal)
        return distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal)

    closeness_scores = np.apply_along_axis(
        lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution),
        axis=1,
        arr=fuzzy_matrix
    )

    return np.mean(closeness_scores)

# Step 6: Perform sensitivity analysis
sensitivity_weights = [
    np.array([
        [0.04, 0.062, 0.095],
        [0.069, 0.103, 0.15],
        [0.403, 0.552, 0.75],
        [0.165, 0.238, 0.342],
        [0.032, 0.046, 0.074]
    ]),
    np.array([
        [0.041, 0.063, 0.096],
        [0.07, 0.104, 0.151],
        [0.404, 0.553, 0.751],
        [0.166, 0.239, 0.343],
        [0.033, 0.047, 0.075]
    ]),
    np.array([
        [0.042, 0.064, 0.097],
        [0.071, 0.105, 0.152],
        [0.405, 0.554, 0.752],
        [0.167, 0.24, 0.344],
        [0.034, 0.048, 0.076]
    ])
]

results = []
results.append(fuzzy_topsis(data, initial_weights))
for weights in sensitivity_weights:
    results.append(fuzzy_topsis(data, weights))

# Step 7: Print the results
for i, result in enumerate(results):
    print(f"Sensitivity Weight {i+1}: {result}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-dbd74914ccca> in <cell line: 40>()
#      38
#      39 # Step 3: Calculate the Fuzzy Decision Matrix
# ---> 40 fuzzy_matrix = data * initial_weights.T
#      41
#      42 # Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
#
# ValueError: operands could not be broadcast together with shapes (18,5) (3,5)

# %%
import numpy as np
from scipy.spatial import distance
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import rankdata
import pandas as pd
import skfuzzy as fuzz

# Step 1: Define the dataset
data = np.array([
    [84, 75, 40, 187, 3],
    [76, 77, 30, 195, 2],
    [27, 85, 25, 272, 4],
    [110, 86, 22, 236, 5],
    [94, 74, 38, 287, 3],
    [102, 62, 10, 242, 6],
    [82, 73, 24, 168, 3],
    [63, 92, 38, 396, 5],
    [55, 77, 26, 144, 2],
    [61, 69, 18, 137, 3],
    [122, 54, 24, 142, 6],
    [75, 57, 30, 196, 5],
    [80, 77, 55, 247, 1],
    [121, 61, 39, 148, 3],
    [125, 69, 8, 294, 4],
    [76, 94, 6, 249, 6],
    [114, 88, 55, 121, 2],
    [65, 78, 48, 269, 1]
])

# Step 2: Define the initial weights
initial_weights = np.array([
    [0.04, 0.069, 0.403, 0.165, 0.032],
    [0.062, 0.103, 0.552, 0.238, 0.046],
    [0.095, 0.15, 0.75, 0.342, 0.074]
])

# Step 3: Calculate the Fuzzy Decision Matrix
fuzzy_matrix = data * initial_weights.T

# Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
ideal_solution = fuzzy_matrix.max(axis=1)
negative_ideal_solution = fuzzy_matrix.min(axis=1)

# Step 5: Define the fuzzy TOPSIS function
def fuzzy_topsis(data, weights):
    fuzzy_matrix = data.T * weights
    ideal_solution = fuzzy_matrix.max(axis=1)
    negative_ideal_solution = fuzzy_matrix.min(axis=1)

    def calculate_closeness(row, ideal, negative_ideal):
        distance_to_ideal = fuzz.euclidean(row, ideal)
        distance_to_negative_ideal = fuzz.euclidean(row, negative_ideal)
        return distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal)

    closeness_scores = np.apply_along_axis(
        lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution),
        axis=1,
        arr=fuzzy_matrix
    )

    return np.mean(closeness_scores)

# Step 6: Perform sensitivity analysis
sensitivity_weights = [
    np.array([
        [0.041, 0.07, 0.404, 0.166, 0.033],
        [0.063, 0.104, 0.553, 0.239, 0.047],
        [0.096, 0.151, 0.751, 0.343, 0.075]
    ]),
    np.array([
        [0.042, 0.071, 0.405, 0.167, 0.034],
        [0.064, 0.105, 0.554, 0.24, 0.048],
        [0.097, 0.152, 0.752, 0.344, 0.076]
    ])
]

results = []
results.append(fuzzy_topsis(data, initial_weights))
for weights in sensitivity_weights:
    results.append(fuzzy_topsis(data, weights))

# Step 7: Print the results
for i, result in enumerate(results):
    print(f"Sensitivity Weight {i+1}: {result}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-773d5dd1c015> in <cell line: 38>()
#      36
#      37 # Step 3: Calculate the Fuzzy Decision Matrix
# ---> 38 fuzzy_matrix = data * initial_weights.T
#      39
#      40 # Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
#
# ValueError: operands could not be broadcast together with shapes (18,5) (5,3)

# %%
import numpy as np
from scipy.spatial import distance
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import rankdata
import pandas as pd
import skfuzzy as fuzz

# Step 1: Define the dataset
data = np.array([
    [84, 75, 40, 187, 3],
    [76, 77, 30, 195, 2],
    [27, 85, 25, 272, 4],
    [110, 86, 22, 236, 5],
    [94, 74, 38, 287, 3],
    [102, 62, 10, 242, 6],
    [82, 73, 24, 168, 3],
    [63, 92, 38, 396, 5],
    [55, 77, 26, 144, 2],
    [61, 69, 18, 137, 3],
    [122, 54, 24, 142, 6],
    [75, 57, 30, 196, 5],
    [80, 77, 55, 247, 1],
    [121, 61, 39, 148, 3],
    [125, 69, 8, 294, 4],
    [76, 94, 6, 249, 6],
    [114, 88, 55, 121, 2],
    [65, 78, 48, 269, 1]
])

# Step 2: Define the initial weights
initial_weights = np.array([
    [0.04, 0.069, 0.403, 0.165, 0.032],
    [0.062, 0.103, 0.552, 0.238, 0.046],
    [0.095, 0.15, 0.75, 0.342, 0.074]
])

# Step 3: Calculate the Fuzzy Decision Matrix
fuzzy_matrix = data * np.tile(initial_weights.T, (data.shape[0], 1))

# Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
ideal_solution = fuzzy_matrix.max(axis=0)
negative_ideal_solution = fuzzy_matrix.min(axis=0)

# Step 5: Define the fuzzy TOPSIS function
def fuzzy_topsis(data, weights):
    fuzzy_matrix = data * np.tile(weights, (data.shape[0], 1))
    ideal_solution = fuzzy_matrix.max(axis=0)
    negative_ideal_solution = fuzzy_matrix.min(axis=0)

    def calculate_closeness(row, ideal, negative_ideal):
        distance_to_ideal = fuzz.euclidean(row, ideal)
        distance_to_negative_ideal = fuzz.euclidean(row, negative_ideal)
        return distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal)

    closeness_scores = np.apply_along_axis(
        lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution),
        axis=1,
        arr=fuzzy_matrix
    )
    return closeness_scores

# Step 6: Perform sensitivity analysis
sensitivity_weights = [
    np.array([
        [0.041, 0.07, 0.404, 0.166, 0.033],
        [0.063, 0.104, 0.553, 0.239, 0.047],
        [0.096, 0.151, 0.751, 0.343, 0.075]
    ]),
    np.array([
        [0.042, 0.071, 0.405, 0.167, 0.034],
        [0.064, 0.105, 0.554, 0.24, 0.048],
        [0.097, 0.152, 0.752, 0.344, 0.076]
    ])
]

results = []
results.append(fuzzy_topsis(data, initial_weights))
for weights in sensitivity_weights:
    results.append(fuzzy_topsis(data, weights))

# Step 7: Print the results
for i, result in enumerate(results):
    print(f"Sensitivity Weight {i+1}: {result}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-3fe089086603> in <cell line: 38>()
#      36
#      37 # Step 3: Calculate the Fuzzy Decision Matrix
# ---> 38 fuzzy_matrix = data * np.tile(initial_weights.T, (data.shape[0], 1))
#      39
#      40 # Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
#
# ValueError: operands could not be broadcast together with shapes (18,5) (90,3)

# %%
import numpy as np
from scipy.spatial import distance
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import rankdata
import pandas as pd
import skfuzzy as fuzz

# Step 1: Define the dataset
data = np.array([
    [84, 75, 40, 187, 3],
    [76, 77, 30, 195, 2],
    [27, 85, 25, 272, 4],
    [110, 86, 22, 236, 5],
    [94, 74, 38, 287, 3],
    [102, 62, 10, 242, 6],
    [82, 73, 24, 168, 3],
    [63, 92, 38, 396, 5],
    [55, 77, 26, 144, 2],
    [61, 69, 18, 137, 3],
    [122, 54, 24, 142, 6],
    [75, 57, 30, 196, 5],
    [80, 77, 55, 247, 1],
    [121, 61, 39, 148, 3],
    [125, 69, 8, 294, 4],
    [76, 94, 6, 249, 6],
    [114, 88, 55, 121, 2],
    [65, 78, 48, 269, 1]
])

# Step 2: Define the initial weights
initial_weights = np.array([
    [0.04, 0.069, 0.403, 0.165, 0.032],
    [0.062, 0.103, 0.552, 0.238, 0.046],
    [0.095, 0.15, 0.75, 0.342, 0.074]
])

# Step 3: Calculate the Fuzzy Decision Matrix
fuzzy_matrix = data.T * np.tile(initial_weights, (data.shape[1],1)).T

# Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
ideal_solution = fuzzy_matrix.max(axis=0)
negative_ideal_solution = fuzzy_matrix.min(axis=0)

# Step 5: Define the fuzzy TOPSIS function
def fuzzy_topsis(data, weights):
    fuzzy_matrix = data * np.tile(weights, (data.shape[0], 1))
    ideal_solution = fuzzy_matrix.max(axis=0)
    negative_ideal_solution = fuzzy_matrix.min(axis=0)

    def calculate_closeness(row, ideal, negative_ideal):
        distance_to_ideal = fuzz.euclidean(row, ideal)
        distance_to_negative_ideal = fuzz.euclidean(row, negative_ideal)
        return distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal)

    closeness_scores = np.apply_along_axis(
        lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution),
        axis=1,
        arr=fuzzy_matrix
    )
    return closeness_scores

# Step 6: Perform sensitivity analysis
sensitivity_weights = [
    np.array([
        [0.041, 0.07, 0.404, 0.166, 0.033],
        [0.063, 0.104, 0.553, 0.239, 0.047],
        [0.096, 0.151, 0.751, 0.343, 0.075]
    ]),
    np.array([
        [0.042, 0.071, 0.405, 0.167, 0.034],
        [0.064, 0.105, 0.554, 0.24, 0.048],
        [0.097, 0.152, 0.752, 0.344, 0.076]
    ])
]

results = []
results.append(fuzzy_topsis(data, initial_weights))
for weights in sensitivity_weights:
    results.append(fuzzy_topsis(data, weights))

# Step 7: Print the results
for i, result in enumerate(results):
    print(f"Sensitivity Weight {i+1}: {result}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-44bc4be74d38> in <cell line: 38>()
#      36
#      37 # Step 3: Calculate the Fuzzy Decision Matrix
# ---> 38 fuzzy_matrix = data.T * np.tile(initial_weights, (data.shape[1],1)).T
#      39
#      40 # Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
#
# ValueError: operands could not be broadcast together with shapes (5,18) (5,15)

# %%
import numpy as np
from scipy.spatial import distance
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import rankdata
import pandas as pd
import skfuzzy as fuzz

# Step 1: Define the dataset
data = np.array([
    [84, 75, 40, 187, 3],
    [76, 77, 30, 195, 2],
    [27, 85, 25, 272, 4],
    [110, 86, 22, 236, 5],
    [94, 74, 38, 287, 3],
    [102, 62, 10, 242, 6],
    [82, 73, 24, 168, 3],
    [63, 92, 38, 396, 5],
    [55, 77, 26, 144, 2],
    [61, 69, 18, 137, 3],
    [122, 54, 24, 142, 6],
    [75, 57, 30, 196, 5],
    [80, 77, 55, 247, 1],
    [121, 61, 39, 148, 3],
    [125, 69, 8, 294, 4],
    [76, 94, 6, 249, 6],
    [114, 88, 55, 121, 2],
    [65, 78, 48, 269, 1]
])

# Step 2: Define the initial weights
initial_weights = np.array([
    [0.04, 0.062, 0.095],
    [0.069, 0.103, 0.15],
    [0.403, 0.552, 0.75],
    [0.165, 0.238, 0.342],
    [0.032, 0.046, 0.074]
])

# Step 3: Calculate the Fuzzy Decision Matrix
fuzzy_matrix = data.T * np.tile(initial_weights[0], (data.shape[0], 1))

# Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
ideal_solution = fuzzy_matrix.max(axis=0)
negative_ideal_solution = fuzzy_matrix.min(axis=0)

# Step 5: Define the fuzzy TOPSIS function
def fuzzy_topsis(data, weights):
    fuzzy_matrix = data * np.tile(weights, (data.shape[0], 1))
    ideal_solution = fuzzy_matrix.max(axis=0)
    negative_ideal_solution = fuzzy_matrix.min(axis=0)

    def calculate_closeness(row, ideal, negative_ideal):
        distance_to_ideal = fuzz.euclidean(row, ideal)
        distance_to_negative_ideal = fuzz.euclidean(row, negative_ideal)
        return distance_to_negative_ideal / (distance_to_ideal + distance_to_negative_ideal)

    closeness_scores = np.apply_along_axis(
        lambda row: calculate_closeness(row, ideal_solution, negative_ideal_solution),
        axis=1,
        arr=fuzzy_matrix
    )
    return closeness_scores

# Step 6: Perform sensitivity analysis
sensitivity_weights = [
    np.array([
        [0.041, 0.063, 0.097],
        [0.07, 0.105, 0.152],
        [0.404, 0.554, 0.752],
        [0.167, 0.24, 0.344],
        [0.034, 0.048, 0.076]
    ]),
    np.array([
        [0.042, 0.064, 0.098],
        [0.071, 0.106, 0.153],
        [0.405, 0.555, 0.753],
        [0.168, 0.241, 0.345],
        [0.035, 0.049, 0.077]
    ]),
    np.array([
        [0.043, 0.065, 0.099],
        [0.072, 0.107, 0.154],
        [0.406, 0.556, 0.754],
        [0.169, 0.242, 0.346],
        [0.036, 0.05, 0.078]
    ])
]

results = []
results.append(fuzzy_topsis(data, initial_weights))
for weights in sensitivity_weights:
    results.append(fuzzy_topsis(data, weights))

# Step 7: Print the results
for i, result in enumerate(results):
    print(f"Sensitivity Weight {i+1}: {result}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-f3513b7e995c> in <cell line: 40>()
#      38
#      39 # Step 3: Calculate the Fuzzy Decision Matrix
# ---> 40 fuzzy_matrix = data.T * np.tile(initial_weights[0], (data.shape[0], 1))
#      41
#      42 # Step 4: Determine the Fuzzy Ideal and Negative-Ideal Solutions
#
# ValueError: operands could not be broadcast together with shapes (5,18) (18,3)
